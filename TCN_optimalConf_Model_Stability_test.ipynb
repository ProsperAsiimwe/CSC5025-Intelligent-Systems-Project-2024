# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
import time

# %%
#Baseline configuration from test made on the MLP model
data = pd.read_csv('JSE_clean_truncated.csv')

# Define horizons and input windows (as per your task)
horizon = 1
input_window = 120

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
data.head()
# Out:
#    ASPEN  CAPITEC  IMPLATS  GROWPNT  NORTHAM  ANGGOLD     BATS  EXXARO  \
# 0   5162   3850.0    16150     1310   3210.0  30250.0  22559.0  7551.0
# 1   5058   3800.0    16650     1350   3257.0  30050.0  22071.0  7700.0
# 2   4950   3800.0    16960     1350   3062.0  30960.0  21613.0  7755.0
# 3   4900   3825.0    16080     1350   3200.0  30650.0  22052.0  7451.0
# 4   4801   3825.0    17318     1350   3205.0  31521.0  21900.0  7849.0
#
#    WOOLIES  NASPERS-N-  ...  INVPLC  DISCOVERY  AMPLATS  ANGLO  FIRSTRAND  \
# 0   1210.0     19587.0  ...  4249.0     2705.0    49500  19680     1182.0
# 1   1240.0     19762.0  ...  4430.0     2750.0    51200  20800     1207.0
# 2   1250.0     18818.0  ...  4320.0     2700.0    50300  21395     1165.0
# 3   1208.0     19472.0  ...  4160.0     2691.0    51700  20850     1190.0
# 4   1210.0     19637.0  ...  4240.0     2733.0    51910  21300     1149.0
#
#    NEDBANK  SASOL    SPAR  VODACOM  MTN_GROUP
# 0   8825.0  29950  5450.0   5880.0    11425.0
# 1   9370.0  30430  5500.0   5680.0    11900.0
# 2   9200.0  30499  5450.0   5680.0    12201.0
# 3   9000.0  29450  5516.0   5560.0    11800.0
# 4   9132.0  30460  5600.0   5675.0    11900.0
#
# [5 rows x 30 columns]

# %%
class TCN(nn.Module):
    def __init__(self, input_dim, output_dim, num_channels, kernel_size=3, dropout=0.2):
        super(TCN, self).__init__()
        self.num_channels = num_channels
        self.input_dim = input_dim
        self.output_dim = output_dim
        
        layers = []
        for i in range(len(num_channels) - 1):
            layers.append(nn.Conv1d(in_channels=num_channels[i], out_channels=num_channels[i+1], kernel_size=kernel_size, dilation=2))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(dropout))
        
        self.tcn = nn.Sequential(*layers)
        self.output_layer = nn.Linear(num_channels[-1], output_dim)
    
    def forward(self, x):
        x = self.tcn(x)
        x = x[:, :, -1]  # Get the last output
        return self.output_layer(x)

# %%
# Function to create sliding window input-output pairs
def create_sequences(data, window_size, horizon):
    X = []
    y = []
    for i in range(len(data) - window_size - horizon):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size:i+window_size+horizon])
    return np.array(X), np.array(y)

# %%
# Training function
# Initialize loss function and optimizer
criterion = nn.MSELoss()

def train_model(model, train_loader, num_epochs=100):
    model.train()
    for epoch in range(num_epochs):
        running_loss = 0.0
        for X_batch, y_batch in train_loader:
            # Transfer the batch to the device (GPU or CPU)
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            
            optimizer.zero_grad()
            y_pred = model(X_batch)
            loss = criterion(y_pred, y_batch)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        #print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_loader):.4f}')

# %%
# Evaluation function to calculate MAE, MAPE, and RMSE
from sklearn.metrics import mean_absolute_error, mean_squared_error

def evaluate_model(model, X_test, y_test):
    model.eval()
    with torch.no_grad():
        y_pred = model(X_test).cpu().numpy()
        y_test = y_test.cpu().numpy()
        
        # Mean Absolute Error (MAE)
        mae = mean_absolute_error(y_test, y_pred)
        
        # Mean Absolute Percentage Error (MAPE)
        mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
        
        # Root Mean Square Error (RMSE)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        
        return mae, mape, rmse

# %%
# Loop over all companies (assumed to be columns in the data)
for company_idx in range(data.shape[1]):  # Assuming there are 30 columns, one per company
    print(f"\nTraining for company {company_idx+1}")
    
    # Extract data for the current company
    company_data = data.iloc[:, company_idx].values

    # Normalize the company data (optional, but recommended)
    company_data = (company_data - np.mean(company_data)) / np.std(company_data)

    print(f"\n--- Horizon: {horizon}, Input Window: {input_window} ---")

    # Create sequences for the current horizon and input window
    X, y = create_sequences(company_data, input_window, horizon)

    # Split the data into train and test sets (e.g., 80-20 split)
    split_idx = int(0.8 * len(X))
    X_train, y_train = X[:split_idx], y[:split_idx]
    X_test, y_test = X[split_idx:], y[split_idx:]

    # Convert the data to PyTorch tensors and move to the correct device
    X_train_tensor = torch.Tensor(X_train).unsqueeze(1).to(device)  # Adding a channel dimension
    y_train_tensor = torch.Tensor(y_train).to(device)
    X_test_tensor = torch.Tensor(X_test).unsqueeze(1).to(device)
    y_test_tensor = torch.Tensor(y_test).to(device)

    # Create DataLoader for batch processing
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

    # Initialize the TCN model
    input_dim = 1  # Single input feature (one company's share price)
    output_dim = horizon  # Predict 'horizon' days into the future
    num_channels = [input_dim] + [1, 32, 64]  # Example channel structure, can be tuned
    kernel_size = 3  # Standard TCN kernel size

    model = TCN(input_dim, output_dim, num_channels, kernel_size).to(device)

    # Initialize optimizer
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # Start time tracking
    start_time = time.time()

    # Train the model
    train_model(model, train_loader, num_epochs=100)

    # End time tracking
    end_time = time.time()

    # Calculate total training time
    training_time = end_time - start_time
    print(f"Training time for company {company_idx+1}, Horizon {horizon}, Input Window {input_window}: {training_time:.2f} seconds")

    # Evaluate the model using MAE, MAPE, RMSE
    mae, mape, rmse = evaluate_model(model, X_test_tensor, y_test_tensor)
    print(f"Test MAE: {mae:.4f}, MAPE: {mape:.2f}%, RMSE: {rmse:.4f}")
# Out:
# Training for company 1
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 1, Horizon 1, Input Window 120: 36.44 seconds
# Test MAE: 0.0816, MAPE: 13.04%, RMSE: 0.1024
#
# Training for company 2
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 2, Horizon 1, Input Window 120: 35.93 seconds
# Test MAE: 0.6502, MAPE: 42.91%, RMSE: 0.6871
#
# Training for company 3
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 3, Horizon 1, Input Window 120: 36.52 seconds
# Test MAE: 0.3936, MAPE: 175.36%, RMSE: 0.4768
#
# Training for company 4
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 4, Horizon 1, Input Window 120: 37.90 seconds
# Test MAE: 0.2767, MAPE: 97.06%, RMSE: 0.3421
#
# Training for company 5
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 5, Horizon 1, Input Window 120: 35.00 seconds
# Test MAE: 0.7786, MAPE: 224.65%, RMSE: 0.9408
#
# Training for company 6
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 6, Horizon 1, Input Window 120: 35.38 seconds
# Test MAE: 0.4404, MAPE: 42.75%, RMSE: 0.6959
#
# Training for company 7
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 7, Horizon 1, Input Window 120: 37.57 seconds
# Test MAE: 0.2973, MAPE: 1014.89%, RMSE: 0.3148
#
# Training for company 8
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 8, Horizon 1, Input Window 120: 34.68 seconds
# Test MAE: 0.4290, MAPE: 332.67%, RMSE: 0.4742
#
# Training for company 9
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 9, Horizon 1, Input Window 120: 35.50 seconds
# Test MAE: 0.4228, MAPE: 346.79%, RMSE: 0.4379
#
# Training for company 10
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 10, Horizon 1, Input Window 120: 35.42 seconds
# Test MAE: 0.1459, MAPE: 16.95%, RMSE: 0.1831
#
# Training for company 11
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 11, Horizon 1, Input Window 120: 35.75 seconds
# Test MAE: 0.5522, MAPE: 32.08%, RMSE: 0.6260
#
# Training for company 12
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 12, Horizon 1, Input Window 120: 22.91 seconds
# Test MAE: 0.4912, MAPE: 48.54%, RMSE: 0.5239
#
# Training for company 13
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 13, Horizon 1, Input Window 120: 21.67 seconds
# Test MAE: 0.2022, MAPE: 326.27%, RMSE: 0.2402
#
# Training for company 14
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 14, Horizon 1, Input Window 120: 20.54 seconds
# Test MAE: 0.1898, MAPE: 97.66%, RMSE: 0.2169
#
# Training for company 15
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 15, Horizon 1, Input Window 120: 21.08 seconds
# Test MAE: 0.5446, MAPE: 298.46%, RMSE: 0.6840
#
# Training for company 16
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 16, Horizon 1, Input Window 120: 18.91 seconds
# Test MAE: 0.5385, MAPE: 64.01%, RMSE: 0.5644
#
# Training for company 17
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 17, Horizon 1, Input Window 120: 17.76 seconds
# Test MAE: 0.3167, MAPE: 111.41%, RMSE: 0.3910
#
# Training for company 18
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 18, Horizon 1, Input Window 120: 16.05 seconds
# Test MAE: 0.4610, MAPE: 220.80%, RMSE: 0.4777
#
# Training for company 19
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 19, Horizon 1, Input Window 120: 15.84 seconds
# Test MAE: 0.4476, MAPE: 62.23%, RMSE: 0.5059
#
# Training for company 20
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 20, Horizon 1, Input Window 120: 15.92 seconds
# Test MAE: 0.0871, MAPE: 10.47%, RMSE: 0.1138
#
# Training for company 21
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 21, Horizon 1, Input Window 120: 15.85 seconds
# Test MAE: 0.4766, MAPE: 72.84%, RMSE: 0.5448
#
# Training for company 22
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 22, Horizon 1, Input Window 120: 15.98 seconds
# Test MAE: 0.3825, MAPE: 163.54%, RMSE: 0.4040
#
# Training for company 23
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 23, Horizon 1, Input Window 120: 15.88 seconds
# Test MAE: 1.2596, MAPE: 66.52%, RMSE: 1.6167
#
# Training for company 24
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 24, Horizon 1, Input Window 120: 20.03 seconds
# Test MAE: 0.6837, MAPE: 68.20%, RMSE: 0.7174
#
# Training for company 25
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 25, Horizon 1, Input Window 120: 22.92 seconds
# Test MAE: 0.4053, MAPE: 152.15%, RMSE: 0.4490
#
# Training for company 26
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 26, Horizon 1, Input Window 120: 22.11 seconds
# Test MAE: 0.3101, MAPE: 30.95%, RMSE: 0.3820
#
# Training for company 27
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 27, Horizon 1, Input Window 120: 21.61 seconds
# Test MAE: 0.8276, MAPE: 62.73%, RMSE: 1.0570
#
# Training for company 28
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 28, Horizon 1, Input Window 120: 21.94 seconds
# Test MAE: 0.4168, MAPE: 50.02%, RMSE: 0.4311
#
# Training for company 29
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 29, Horizon 1, Input Window 120: 21.59 seconds
# Test MAE: 0.1950, MAPE: 173.63%, RMSE: 0.2341
#
# Training for company 30
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 30, Horizon 1, Input Window 120: 21.49 seconds
# Test MAE: 0.7235, MAPE: 65.54%, RMSE: 0.7342

# %%
# Loop over all companies (assumed to be columns in the data)
for company_idx in range(data.shape[1]):  # Assuming there are 30 columns, one per company
    print(f"\nTraining for company {company_idx+1}")
    
    # Extract data for the current company
    company_data = data.iloc[:, company_idx].values

    # Normalize the company data (optional, but recommended)
    company_data = (company_data - np.mean(company_data)) / np.std(company_data)

    print(f"\n--- Horizon: {horizon}, Input Window: {input_window} ---")

    # Create sequences for the current horizon and input window
    X, y = create_sequences(company_data, input_window, horizon)

    # Split the data into train and test sets (e.g., 80-20 split)
    split_idx = int(0.8 * len(X))
    X_train, y_train = X[:split_idx], y[:split_idx]
    X_test, y_test = X[split_idx:], y[split_idx:]

    # Convert the data to PyTorch tensors and move to the correct device
    X_train_tensor = torch.Tensor(X_train).unsqueeze(1).to(device)  # Adding a channel dimension
    y_train_tensor = torch.Tensor(y_train).to(device)
    X_test_tensor = torch.Tensor(X_test).unsqueeze(1).to(device)
    y_test_tensor = torch.Tensor(y_test).to(device)

    # Create DataLoader for batch processing
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

    # Initialize the TCN model
    input_dim = 1  # Single input feature (one company's share price)
    output_dim = horizon  # Predict 'horizon' days into the future
    num_channels = [input_dim] + [1, 32, 64]  # Example channel structure, can be tuned
    kernel_size = 3  # Standard TCN kernel size

    model = TCN(input_dim, output_dim, num_channels, kernel_size).to(device)

    # Initialize optimizer
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # Start time tracking
    start_time = time.time()

    # Train the model
    train_model(model, train_loader, num_epochs=100)

    # End time tracking
    end_time = time.time()

    # Calculate total training time
    training_time = end_time - start_time
    print(f"Training time for company {company_idx+1}, Horizon {horizon}, Input Window {input_window}: {training_time:.2f} seconds")

    # Evaluate the model using MAE, MAPE, RMSE
    mae, mape, rmse = evaluate_model(model, X_test_tensor, y_test_tensor)
    print(f"Test MAE: {mae:.4f}, MAPE: {mape:.2f}%, RMSE: {rmse:.4f}")
# Out:
# Training for company 1
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 1, Horizon 1, Input Window 120: 20.81 seconds
# Test MAE: 0.4770, MAPE: 73.04%, RMSE: 0.4844
#
# Training for company 2
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 2, Horizon 1, Input Window 120: 20.99 seconds
# Test MAE: 0.4925, MAPE: 28.68%, RMSE: 0.5959
#
# Training for company 3
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 3, Horizon 1, Input Window 120: 20.52 seconds
# Test MAE: 0.3668, MAPE: 202.97%, RMSE: 0.4630
#
# Training for company 4
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 4, Horizon 1, Input Window 120: 21.44 seconds
# Test MAE: 0.4901, MAPE: 226.60%, RMSE: 0.5621
#
# Training for company 5
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 5, Horizon 1, Input Window 120: 22.18 seconds
# Test MAE: 1.0561, MAPE: 297.48%, RMSE: 1.2968
#
# Training for company 6
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 6, Horizon 1, Input Window 120: 23.09 seconds
# Test MAE: 0.4017, MAPE: 32.80%, RMSE: 0.6764
#
# Training for company 7
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 7, Horizon 1, Input Window 120: 22.26 seconds
# Test MAE: 0.3157, MAPE: 1134.52%, RMSE: 0.3289
#
# Training for company 8
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 8, Horizon 1, Input Window 120: 20.85 seconds
# Test MAE: 0.4991, MAPE: 407.12%, RMSE: 0.5397
#
# Training for company 9
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 9, Horizon 1, Input Window 120: 20.65 seconds
# Test MAE: 0.1372, MAPE: 231.86%, RMSE: 0.1594
#
# Training for company 10
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 10, Horizon 1, Input Window 120: 20.53 seconds
# Test MAE: 0.4946, MAPE: 46.86%, RMSE: 0.5097
#
# Training for company 11
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 11, Horizon 1, Input Window 120: 19.75 seconds
# Test MAE: 0.6106, MAPE: 35.62%, RMSE: 0.6839
#
# Training for company 12
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 12, Horizon 1, Input Window 120: 20.02 seconds
# Test MAE: 0.2786, MAPE: 24.11%, RMSE: 0.3265
#
# Training for company 13
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 13, Horizon 1, Input Window 120: 21.34 seconds
# Test MAE: 0.2017, MAPE: 301.18%, RMSE: 0.2356
#
# Training for company 14
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 14, Horizon 1, Input Window 120: 20.43 seconds
# Test MAE: 0.1420, MAPE: 107.58%, RMSE: 0.1798
#
# Training for company 15
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 15, Horizon 1, Input Window 120: 21.61 seconds
# Test MAE: 0.5875, MAPE: 319.76%, RMSE: 0.7174
#
# Training for company 16
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 16, Horizon 1, Input Window 120: 21.42 seconds
# Test MAE: 0.2897, MAPE: 27.43%, RMSE: 0.4867
#
# Training for company 17
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 17, Horizon 1, Input Window 120: 22.97 seconds
# Test MAE: 0.3637, MAPE: 207.74%, RMSE: 0.4254
#
# Training for company 18
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 18, Horizon 1, Input Window 120: 23.81 seconds
# Test MAE: 0.2457, MAPE: 178.61%, RMSE: 0.2818
#
# Training for company 19
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 19, Horizon 1, Input Window 120: 20.15 seconds
# Test MAE: 0.4739, MAPE: 65.71%, RMSE: 0.5514
#
# Training for company 20
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 20, Horizon 1, Input Window 120: 22.63 seconds
# Test MAE: 0.0815, MAPE: 10.00%, RMSE: 0.1039
#
# Training for company 21
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 21, Horizon 1, Input Window 120: 22.05 seconds
# Test MAE: 1.0157, MAPE: 96.14%, RMSE: 1.2414
#
# Training for company 22
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 22, Horizon 1, Input Window 120: 21.15 seconds
# Test MAE: 0.3220, MAPE: 120.83%, RMSE: 0.3497
#
# Training for company 23
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 23, Horizon 1, Input Window 120: 21.98 seconds
# Test MAE: 2.0538, MAPE: 144.99%, RMSE: 2.3069
#
# Training for company 24
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 24, Horizon 1, Input Window 120: 22.15 seconds
# Test MAE: 0.9370, MAPE: 59.36%, RMSE: 1.2911
#
# Training for company 25
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 25, Horizon 1, Input Window 120: 21.89 seconds
# Test MAE: 0.1767, MAPE: 145.96%, RMSE: 0.2158
#
# Training for company 26
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 26, Horizon 1, Input Window 120: 22.52 seconds
# Test MAE: 0.3446, MAPE: 38.67%, RMSE: 0.4130
#
# Training for company 27
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 27, Horizon 1, Input Window 120: 22.72 seconds
# Test MAE: 0.7592, MAPE: 64.15%, RMSE: 0.9929
#
# Training for company 28
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 28, Horizon 1, Input Window 120: 25.00 seconds
# Test MAE: 0.0904, MAPE: 14.36%, RMSE: 0.1189
#
# Training for company 29
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 29, Horizon 1, Input Window 120: 23.23 seconds
# Test MAE: 0.3235, MAPE: 827.87%, RMSE: 0.3395
#
# Training for company 30
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 30, Horizon 1, Input Window 120: 22.40 seconds
# Test MAE: 0.3228, MAPE: 23.88%, RMSE: 0.4239

# %%
# Loop over all companies (assumed to be columns in the data)
for company_idx in range(data.shape[1]):  # Assuming there are 30 columns, one per company
    print(f"\nTraining for company {company_idx+1}")
    
    # Extract data for the current company
    company_data = data.iloc[:, company_idx].values

    # Normalize the company data (optional, but recommended)
    company_data = (company_data - np.mean(company_data)) / np.std(company_data)

    print(f"\n--- Horizon: {horizon}, Input Window: {input_window} ---")

    # Create sequences for the current horizon and input window
    X, y = create_sequences(company_data, input_window, horizon)

    # Split the data into train and test sets (e.g., 80-20 split)
    split_idx = int(0.8 * len(X))
    X_train, y_train = X[:split_idx], y[:split_idx]
    X_test, y_test = X[split_idx:], y[split_idx:]

    # Convert the data to PyTorch tensors and move to the correct device
    X_train_tensor = torch.Tensor(X_train).unsqueeze(1).to(device)  # Adding a channel dimension
    y_train_tensor = torch.Tensor(y_train).to(device)
    X_test_tensor = torch.Tensor(X_test).unsqueeze(1).to(device)
    y_test_tensor = torch.Tensor(y_test).to(device)

    # Create DataLoader for batch processing
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

    # Initialize the TCN model
    input_dim = 1  # Single input feature (one company's share price)
    output_dim = horizon  # Predict 'horizon' days into the future
    num_channels = [input_dim] + [1, 32, 64]  # Example channel structure, can be tuned
    kernel_size = 3  # Standard TCN kernel size

    model = TCN(input_dim, output_dim, num_channels, kernel_size).to(device)

    # Initialize optimizer
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # Start time tracking
    start_time = time.time()

    # Train the model
    train_model(model, train_loader, num_epochs=100)

    # End time tracking
    end_time = time.time()

    # Calculate total training time
    training_time = end_time - start_time
    print(f"Training time for company {company_idx+1}, Horizon {horizon}, Input Window {input_window}: {training_time:.2f} seconds")

    # Evaluate the model using MAE, MAPE, RMSE
    mae, mape, rmse = evaluate_model(model, X_test_tensor, y_test_tensor)
    print(f"Test MAE: {mae:.4f}, MAPE: {mape:.2f}%, RMSE: {rmse:.4f}")
# Out:
# Training for company 1
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 1, Horizon 1, Input Window 120: 21.49 seconds
# Test MAE: 0.0650, MAPE: 11.80%, RMSE: 0.0831
#
# Training for company 2
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 2, Horizon 1, Input Window 120: 22.61 seconds
# Test MAE: 1.8836, MAPE: 126.65%, RMSE: 1.9512
#
# Training for company 3
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 3, Horizon 1, Input Window 120: 21.51 seconds
# Test MAE: 0.3521, MAPE: 191.20%, RMSE: 0.4406
#
# Training for company 4
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 4, Horizon 1, Input Window 120: 22.45 seconds
# Test MAE: 0.4958, MAPE: 230.97%, RMSE: 0.5711
#
# Training for company 5
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 5, Horizon 1, Input Window 120: 21.66 seconds
# Test MAE: 1.9935, MAPE: 698.52%, RMSE: 2.4114
#
# Training for company 6
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 6, Horizon 1, Input Window 120: 22.62 seconds
# Test MAE: 0.4737, MAPE: 39.39%, RMSE: 0.7601
#
# Training for company 7
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 7, Horizon 1, Input Window 120: 22.50 seconds
# Test MAE: 0.2968, MAPE: 1032.59%, RMSE: 0.3193
#
# Training for company 8
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 8, Horizon 1, Input Window 120: 23.90 seconds
# Test MAE: 0.4383, MAPE: 374.32%, RMSE: 0.4726
#
# Training for company 9
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 9, Horizon 1, Input Window 120: 23.92 seconds
# Test MAE: 0.7102, MAPE: 323.43%, RMSE: 0.8099
#
# Training for company 10
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 10, Horizon 1, Input Window 120: 24.09 seconds
# Test MAE: 0.4541, MAPE: 42.92%, RMSE: 0.4684
#
# Training for company 11
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 11, Horizon 1, Input Window 120: 23.26 seconds
# Test MAE: 0.6181, MAPE: 39.08%, RMSE: 0.6368
#
# Training for company 12
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 12, Horizon 1, Input Window 120: 22.77 seconds
# Test MAE: 0.2574, MAPE: 22.41%, RMSE: 0.3010
#
# Training for company 13
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 13, Horizon 1, Input Window 120: 21.53 seconds
# Test MAE: 0.1912, MAPE: 289.35%, RMSE: 0.2313
#
# Training for company 14
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 14, Horizon 1, Input Window 120: 21.07 seconds
# Test MAE: 0.4639, MAPE: 192.46%, RMSE: 0.4989
#
# Training for company 15
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 15, Horizon 1, Input Window 120: 21.87 seconds
# Test MAE: 0.4523, MAPE: 249.08%, RMSE: 0.5587
#
# Training for company 16
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 16, Horizon 1, Input Window 120: 22.08 seconds
# Test MAE: 0.5680, MAPE: 66.29%, RMSE: 0.6013
#
# Training for company 17
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 17, Horizon 1, Input Window 120: 22.37 seconds
# Test MAE: 0.3594, MAPE: 202.32%, RMSE: 0.4278
#
# Training for company 18
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 18, Horizon 1, Input Window 120: 22.74 seconds
# Test MAE: 0.4703, MAPE: 227.38%, RMSE: 0.4943
#
# Training for company 19
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 19, Horizon 1, Input Window 120: 24.29 seconds
# Test MAE: 0.3470, MAPE: 48.33%, RMSE: 0.4031
#
# Training for company 20
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 20, Horizon 1, Input Window 120: 23.30 seconds
# Test MAE: 0.0994, MAPE: 11.60%, RMSE: 0.1310
#
# Training for company 21
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 21, Horizon 1, Input Window 120: 23.63 seconds
# Test MAE: 0.4924, MAPE: 76.34%, RMSE: 0.5793
#
# Training for company 22
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 22, Horizon 1, Input Window 120: 23.85 seconds
# Test MAE: 0.4117, MAPE: 170.52%, RMSE: 0.4339
#
# Training for company 23
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 23, Horizon 1, Input Window 120: 22.45 seconds
# Test MAE: 2.0919, MAPE: 148.89%, RMSE: 2.3452
#
# Training for company 24
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 24, Horizon 1, Input Window 120: 20.56 seconds
# Test MAE: 0.8958, MAPE: 87.27%, RMSE: 0.9754
#
# Training for company 25
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 25, Horizon 1, Input Window 120: 21.81 seconds
# Test MAE: 0.1900, MAPE: 147.54%, RMSE: 0.2327
#
# Training for company 26
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 26, Horizon 1, Input Window 120: 20.84 seconds
# Test MAE: 0.4149, MAPE: 40.47%, RMSE: 0.4880
#
# Training for company 27
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 27, Horizon 1, Input Window 120: 21.84 seconds
# Test MAE: 0.7748, MAPE: 63.02%, RMSE: 1.0073
#
# Training for company 28
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 28, Horizon 1, Input Window 120: 22.92 seconds
# Test MAE: 0.4943, MAPE: 62.93%, RMSE: 0.5027
#
# Training for company 29
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 29, Horizon 1, Input Window 120: 20.37 seconds
# Test MAE: 0.2909, MAPE: 705.83%, RMSE: 0.3079
#
# Training for company 30
#
# --- Horizon: 1, Input Window: 120 ---
# Training time for company 30, Horizon 1, Input Window 120: 23.83 seconds
# Test MAE: 0.3398, MAPE: 24.51%, RMSE: 0.4493
